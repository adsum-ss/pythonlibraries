# %%
# Basic Library
import numpy as np
import pandas as pd

# Libraries for Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings;
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Format Strings in Plot Function

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]
salary2 = [45372, 48876, 53850, 57287, 63016, 65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.plot(age,salary,'g+');

# %%
plt.plot(age,salary,'g+-');

# %%
plt.plot(age,salary,'*--r');

# %%
plt.plot(age,salary,'bD');

# %%
plt.plot(age,salary, color='orange', marker='D', linestyle='');

# %%
plt.plot(age,salary, color='#888840', marker='o', linestyle='', markersize=10);

# %%
plt.plot(age,salary,alpha=1);

# %%
plt.plot(age,salary,alpha=0.2);  # 'alpha' sets the transparency

# %% [markdown]
# ## Linestyles (ls)

# %%
x = np.arange(0,10)

# %%
# possible linestype options ‘--‘, ‘–’, ‘-.’, ‘:’, ‘steps’

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x-1, color="green", lw=3, linestyle='-')  # solid
ax.plot(x, x-2, color="green", lw=3, ls='-.')        # dash and dot
ax.plot(x, x-3, color="green", lw=3, ls=':')         # dots
ax.plot(x, x-4, color="green", lw=3, ls='--')        # dashes

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))

# Use marker for string code
# Use markersize or ms for size

ax.plot(x, x-1,marker='+',markersize=20)
ax.plot(x, x-2,marker='o',ms=20)           # ms can be used for markersize
ax.plot(x, x-3,marker='s',ms=20,lw=0)      # make linewidth zero to see only markers
ax.plot(x, x-4,marker='1',ms=20)

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.suptitle("LineStyles & Markers & Markersize & Color",fontsize=16, y = 1.2)

plt.subplot(2,2,1)
plt.plot(age, salary, "r", ls="-", marker="+" ,markersize=30)

plt.subplot(2,2,2)
plt.plot(age, salary2, "b",ls="-.", marker="o" ,markersize=30)

plt.subplot(2,2,3)
plt.plot(age, salary, "g",ls=":", marker="x" ,markersize=30)

plt.subplot(2,2,4)
plt.plot(age, salary2, "y",ls="--" ,marker="*" ,markersize=30)


plt.tight_layout();

plt.show()

# %%
# color = "#ff00ff" RGB hex code

# %%
fig, ax = plt.subplots(2,2,figsize=(15,8))

ax[0,0].plot(age,salary, "r", ls="-", marker="+" ,markersize=30)
ax[0,0].set_title("salary by age")

ax[0,1].plot(age, salary2, "b", ls="-.", marker="o" ,markersize=30)
ax[0,1].set_title("salary2 by age")

ax[1,0].plot(age,salary, "g", ls=":", marker="x" ,markersize=30)
ax[1,0].set_title("salary by age")

ax[1,1].plot(age, salary2, "y", ls="--", marker="*" ,markersize=30)
ax[1,1].set_title("salary2 by age")

fig.suptitle("LineStyles & Markers & Markersize & Color",fontsize=26)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Line Width

# %%
fig, ax = plt.subplots(figsize=(12,6))

fig.suptitle("To change the line width, we can use the 'linewidth' or 'lw' keyword argument",fontsize=18)

ax.plot(x, x-1, color="red", linewidth=0.25)
ax.plot(x, x-2, color="red", lw=0.50)
ax.plot(x, x-3, color="red", lw=1)
ax.plot(x, x-4, color="red", lw=10)

plt.show()

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(x, y, color='green', linewidth=5, linestyle='dashdot')

# %%
aa = np.linspace(0, 5, 11)
bb = aa ** 2

fig, ax = plt.subplots(figsize=(8,4))
ax.plot(aa, bb, color="red", lw=3, ls='-', marker='o', markersize=10)

# %%
x = np.linspace(1, 5, 11)

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+13, color="green", lw=3, ls='-', marker='p', markersize=10)

# %%
x = np.linspace(1, 5, 11)
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+13, color="green", lw=3, ls='-', marker='p', markersize=10)

ax.set_xlim([0, 7])
ax.set_ylim([13, 20])
# Out:
# (13.0, 20.0)
