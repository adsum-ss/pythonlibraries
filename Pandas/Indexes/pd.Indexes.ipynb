# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Load Titanic Dataset
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[5:10]  # indexing with rows; only with "5" we get key error
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df[2:4]
# Out:
#    survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 2         1       3  female  26.0      0      0   7.925        S  Third
# 3         1       1  female  35.0      1      0  53.100        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
df["embark_town"].head()
# df.embark_town
# Out:
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# Name: embark_town, dtype: object

# %%
df[["embark_town"]].head()
# Out:
#    embark_town
# 0  Southampton
# 1    Cherbourg
# 2  Southampton
# 3  Southampton
# 4  Southampton

# %%
type(df["embark_town"])
# Out:
# pandas.core.series.Series

# %%
type(df[["embark_town"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["survived", "class"]]  # for multiple columns, you must use square brackets
# Out:
#      survived   class
# 0           0   Third
# 1           1   First
# 2           1   Third
# 3           1   First
# 4           0   Third
# ..        ...     ...
# 886         0  Second
# 887         1   First
# 888         0   Third
# 889         1   First
# 890         0   Third
#
# [891 rows x 2 columns]

# %%
df["embark_town"][0]
# Out:
# 'Southampton'

# %%
df[["embark_town", "class"]][:10:2]
# Out:
#    embark_town  class
# 0  Southampton  Third
# 2  Southampton  Third
# 4  Southampton  Third
# 6  Southampton  First
# 8  Southampton  Third

# %%
df["embark_town":"class"]
# TypeError: cannot do slice indexing on RangeIndex with these indexers [embark_town] of type str

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_random = pd.DataFrame(  np.random.randn(5,4),
                   index = ['A', 'B', 'C', 'D', 'E'],
                   columns = 'WW XX YY ZZ'.split())
df_random
# Out:
#          WW        XX        YY        ZZ
# A -0.624885 -0.238486  1.098093  0.998415
# B  1.054235 -0.483501 -0.347926 -2.483455
# C -1.799045 -0.368882 -0.933223 -0.786166
# D -1.678428 -0.122894 -1.556274 -1.254020
# E -1.028601 -2.830481  0.469858  0.199833

# %%
df_random["WW":"ZZ"]
# Out:
# Empty DataFrame
# Columns: [WW, XX, YY, ZZ]
# Index: []

# %%
df_random["WW":"ZZ"]

# %% [markdown]
# ## loc
#
# <i> Access a group of rows and columns by label(s) or a boolean array.
#
# <i> .loc[] is primarily label based, but may also be used with a boolean array.

# %%
df.loc[0] # we accessed the first row by its label (series)
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
df.loc[[0]] # we accessed the first row by its label (dataframe)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
df.loc[[0, 1]]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
df.loc[0, "embark_town"]
# Out:
# 'Southampton'

# %%
df.loc[0]["embark_town"]
# Out:
# 'Southampton'

# %%
df.loc[[0, 1], "embark_town"]
# Out:
# 0    Southampton
# 1      Cherbourg
# Name: embark_town, dtype: object

# %%
df.loc[[0, 1, 2], ["embark_town"]]
# Out:
#    embark_town
# 0  Southampton
# 1    Cherbourg
# 2  Southampton

# %%
df.loc[[0, 1, 2], ["embark_town", "class"]] # for multiple columns
# Out:
#    embark_town  class
# 0  Southampton  Third
# 1    Cherbourg  First
# 2  Southampton  Third

# %%
df.loc[0:2, "embark_town"] # including stop point
# Out:
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# Name: embark_town, dtype: object

# %%
df.loc["class":"embark_town"]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
df.loc[0:2, "class":"embark_town"]  # including stop point

# when slicing, don't use square brackets
# Out:
#    class    who  adult_male deck  embark_town
# 0  Third    man        True  NaN  Southampton
# 1  First  woman       False    C    Cherbourg
# 2  Third  woman       False  NaN  Southampton

# %%
df.loc[0:2, "class":"embark_town"][::2]
# Out:
#    class    who  adult_male deck  embark_town
# 0  Third    man        True  NaN  Southampton
# 2  Third  woman       False  NaN  Southampton

# %%
df.loc[0:2][["who","embark_town"]]
# Out:
#      who  embark_town
# 0    man  Southampton
# 1  woman    Cherbourg
# 2  woman  Southampton

# %% [markdown]
# ## iloc
#
# <i> Purely integer-location based indexing for selection by position.
#
# <i> .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.

# %%
df.iloc[0]  # first row
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
df.iloc[[0, 1]]  # multiple rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
df.iloc[[0, 1], 3]
# Out:
# 0    22.0
# 1    38.0
# Name: age, dtype: float64

# %%
df.iloc[1:4, 1:4] # stop points not included
# Out:
#    pclass     sex   age
# 1       1  female  38.0
# 2       3  female  26.0
# 3       1  female  35.0

# %%
df.iloc[0:4, [0,2,8,12]]  # don't use square brackets when slicing
# Out:
#    survived     sex  class  embark_town
# 0         0    male  Third  Southampton
# 1         1  female  First    Cherbourg
# 2         1  female  Third  Southampton
# 3         1  female  First  Southampton

# %% [markdown]
# ## indexing with booleans

# %%
df_random = pd.DataFrame(np.random.randint(1,30,size=(5,4)),
                   index = ['A', 'B', 'C', 'D', 'E'],
                   columns = 'W X Y Z'.split())
df_random
# Out:
#     W   X   Y   Z
# A  26  28  29  23
# B  23  14  13  10
# C  17  13  17  12
# D  12   3   6  19
# E  21  11  17  26

# %%
df_random["Y"] > 16
# Out:
# A     True
# B    False
# C     True
# D    False
# E     True
# Name: Y, dtype: bool

# %%
df_random[[True, False, True, False, True]]
# Out:
#     W   X   Y   Z
# A  26  28  29  23
# C  17  13  17  12
# E  21  11  17  26

# %% [markdown]
# ## changing index and column elements

# %%
df1 = pd.DataFrame({"city": ["İzmir", "Paris", "Madrid"],
                    "country": ["Turkey", "France", "Spain"]})
df1
# Out:
#      city country
# 0   İzmir  Turkey
# 1   Paris  France
# 2  Madrid   Spain

# %%
df1.index = ["A", "B", "C"]
df1
# Out:
#      city country
# A   İzmir  Turkey
# B   Paris  France
# C  Madrid   Spain

# %%
df1.columns = ["Şehir", "Ülke"]
df1
# Out:
#     Şehir    Ülke
# A   İzmir  Turkey
# B   Paris  France
# C  Madrid   Spain

# %%
pd.DataFrame(df1.values, columns=["AA", "BB"], index=["X", "Y", "Z"])
# Out:
#        AA      BB
# X   İzmir  Turkey
# Y   Paris  France
# Z  Madrid   Spain

# %% [markdown]
# ## set_index
#
# <i> Set the DataFrame index (row labels) using one or more existing columns or arrays (of the correct length). The index can replace the existing index or expand on it.

# %%
df.index  # it is useful when we look for unique identifiers (but we don't have a unique identifier in this dataset)
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.set_index("embark_town").head()  # it doesn't change the original dataframe
# Out:
#              survived  pclass     sex   age  sibsp  parch     fare embarked  \
# embark_town
# Southampton         0       3    male  22.0      1      0   7.2500        S
# Cherbourg           1       1  female  38.0      1      0  71.2833        C
# Southampton         1       3  female  26.0      0      0   7.9250        S
# Southampton         1       1  female  35.0      1      0  53.1000        S
# Southampton         0       3    male  35.0      0      0   8.0500        S
#
#              class    who  adult_male deck alive  alone
# embark_town
# Southampton  Third    man        True  NaN    no  False
# Cherbourg    First  woman       False    C   yes  False
# Southampton  Third  woman       False  NaN   yes   True
# Southampton  First  woman       False    C   yes  False
# Southampton  Third    man        True  NaN    no   True

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.set_index("embark_town", inplace=True)  # now it will modify the dataframe
df.head()
# Out:
#              survived  pclass     sex   age  sibsp  parch     fare embarked  \
# embark_town
# Southampton         0       3    male  22.0      1      0   7.2500        S
# Cherbourg           1       1  female  38.0      1      0  71.2833        C
# Southampton         1       3  female  26.0      0      0   7.9250        S
# Southampton         1       1  female  35.0      1      0  53.1000        S
# Southampton         0       3    male  35.0      0      0   8.0500        S
#
#              class    who  adult_male deck alive  alone
# embark_town
# Southampton  Third    man        True  NaN    no  False
# Cherbourg    First  woman       False    C   yes  False
# Southampton  Third  woman       False  NaN   yes   True
# Southampton  First  woman       False    C   yes  False
# Southampton  Third    man        True  NaN    no   True

# %%
df.loc["Cherbourg"] # if it was unique it would only return one result, however it can be used for grouping now.
# Out:
#              survived  pclass     sex   age  sibsp  parch     fare embarked  \
# embark_town
# Cherbourg           1       1  female  38.0      1      0  71.2833        C
# Cherbourg           1       2  female  14.0      1      0  30.0708        C
# Cherbourg           1       3  female   NaN      0      0   7.2250        C
# Cherbourg           0       3    male   NaN      0      0   7.2250        C
# Cherbourg           0       1    male  40.0      0      0  27.7208        C
# ...               ...     ...     ...   ...    ...    ...      ...      ...
# Cherbourg           1       2  female  27.0      1      0  13.8583        C
# Cherbourg           1       2  female  28.0      1      0  24.0000        C
# Cherbourg           1       3  female  15.0      0      0   7.2250        C
# Cherbourg           1       1  female  56.0      0      1  83.1583        C
# Cherbourg           1       1    male  26.0      0      0  30.0000        C
#
# ...

# %%
df.loc["Cherbourg", "class"].head()
# Out:
# embark_town
# Cherbourg     First
# Cherbourg    Second
# Cherbourg     Third
# Cherbourg     Third
# Cherbourg     First
# Name: class, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df.loc[0]  # we will get this error since the data frame has no longer index with that label

# %% [markdown]
# ## reset_index
#
# <i> Reset the index, or a level of it.
#
# <i> Reset the index of the DataFrame, and use the default one instead. If the DataFrame has a MultiIndex, this method can remove one or more levels.

# %%
df.reset_index(inplace=True)
df
# Out:
#      embark_town  survived  pclass     sex   age  sibsp  parch     fare  \
# 0    Southampton         0       3    male  22.0      1      0   7.2500
# 1      Cherbourg         1       1  female  38.0      1      0  71.2833
# 2    Southampton         1       3  female  26.0      0      0   7.9250
# 3    Southampton         1       1  female  35.0      1      0  53.1000
# 4    Southampton         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886  Southampton         0       2    male  27.0      0      0  13.0000
# 887  Southampton         1       1  female  19.0      0      0  30.0000
# 888  Southampton         0       3  female   NaN      1      2  23.4500
# 889    Cherbourg         1       1    male  26.0      0      0  30.0000
# 890   Queenstown         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck alive  alone
# ...

# %% [markdown]
# ## sort_index
#
# <i> Sort object by labels (along an axis).
#
# <i> Returns a new DataFrame sorted by label if inplace argument is False, otherwise updates the original DataFrame and returns None.

# %%
# another method to change index label

# %%
schema_df = pd.read_csv("Data/survey_results_schema.csv")
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df = pd.read_csv("Data/survey_results_schema.csv", index_col="Column")
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc["Hobbyist"]
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc["MgrIdiot"]
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc["MgrIdiot", "QuestionText"]
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index()  # sort_index(ascending=False) for reversed index
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
schema_df.head()  # sort_index doesn't modify the dataframe without "inplace"
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
